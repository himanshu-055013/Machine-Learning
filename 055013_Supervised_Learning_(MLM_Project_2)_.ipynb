# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu-055013/Machine-Learning/blob/main/055013_Supervised_Learning_(MLM_Project_2)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Report: Supervised Learning**
#
# ---
#
# ## **Project Information**
# - **Project Title**: Machine Learning Model Analysis for Trade Data
# - **Student Name**: Himanshu Agarwal
# - **Roll Number**: 055013
#
# ---
#
# ## **Description of Data**
# 1. **Dataset Overview**:
#    - **Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#    - **Sample Size**: 5001 entries and 16 columns.
#    - **Type**: Cross-sectional data.
#    - **Structure**: Balanced, complete dataset without missing values.
#
# 2. **Variable Overview**:
#    - **Quantitative Variables**:
#      - `Quantity`: Measures trade volumes.
#      - `Value`: Monetary representation of transactions.
#      - `Weight`: Physical weight of goods.
#    - **Categorical Variables**:
#      - `Country`, `Product`, `Shipping_Method`, `Payment_Terms`, etc.
#    - **Other**:
#      - `Date` column stored as a string, recommended for conversion to datetime format.
#
# 3. **Data Integrity**:
#    - No missing values.
#    - Consistent data types aligned with variable types.
#    - `Transaction_ID` acts as a unique identifier for traceability.
#
# 4. **Potential Use**:
#    - Analyze trends, relationships, and statistical insights.
#    - Train machine learning models for prediction and classification.
#
# ---
#
# ## **Project Objectives and Problem Statements**
#
#
# ### **Supervised Learning Objectives**
# - **Classification**:
#   - Predict shipping methods (`Shipping_Method`) using features like `Quantity` and `Weight`.
#   - Evaluate model performance across algorithms (e.g., Logistic Regression, Decision Tree, Random Forest).
# - **Regression**:
#   - Explore how `Value` can be predicted based on other variables (not done in this report but suggested).
#
# ### **Performance Metrics**:
# - Accuracy, Precision, Recall, F1-Score for classification tasks.
# - Statistical comparisons using confidence intervals, correlation matrices, and significance tests.
#
# ---
#
# ## **Analysis of Data**
#
# ### **Preprocessing Steps**
# 1. **Missing Values**:
#    - No missing values detected in the dataset.
#
# 2. **Encoding**:
#    - Categorical variables were encoded using `OrdinalEncoder` to prepare them for machine learning.
#    - Numeric mappings were validated for consistency.
#
# 3. **Scaling**:
#    - Min-Max Scaling was applied to `Quantity`, `Value`, and `Weight`, normalizing values to [0, 1].
#    - Ensured comparable feature ranges for gradient- and distance-based models.
#
# 4. **Integration**:
#    - Combined scaled and encoded variables into a single dataset (`HA13_sample`), ready for machine learning.
#
# ### **Statistical Summaries**
# 1. **Quantitative Variables**:
#    - **Means**:
#      - `Quantity`: 0.5007
#      - `Value`: 0.5009
#      - `Weight`: 0.4942
#    - **Spread**:
#      - Standard deviations: ~0.29 for all variables, ensuring balanced variability.
#
# 2. **Mode and Variability**:
#    - High Coefficient of Variation (CV): 57–59% across all features.
#    - Symmetrical distributions confirmed via skewness and kurtosis.
#
# 3. **Correlation**:
#    - Minimal linear correlations among variables, supporting feature independence.
#
# 4. **Confidence Intervals**:
#    - Narrow ranges (e.g., `Quantity`: 0.49–0.51), indicating reliable mean estimates.
#
# ### **Inferential Statistics**
# 1. **Chi-Square Test**:
#    - No statistically significant association between tested categorical variables (p = 0.066).
#
# 2. **Normality Tests**:
#    - All numerical variables failed normality tests, requiring non-parametric approaches.
#
# ---
#
# ## **Machine Learning Models**
#
# ### **Model Comparisons**
# 1. **Decision Tree**:
#    - Accuracy: 31.6%.
#    - Challenges:
#      - High misclassification rates.
#      - Overlap in class feature distributions.
#
# 2. **K-Nearest Neighbors (KNN)**:
#    - Accuracy: 32.4%.
#    - Slightly better than Decision Tree but still near random guessing.
#
# 3. **Naive Bayes (NB)**:
#    - Accuracy: 32.0%.
#    - Failed to classify one class (1.0) entirely.
#
# 4. **Logistic Regression**:
#    - Accuracy: 32.2%.
#    - Bias toward one class (2.0).
#
# 5. **Support Vector Machine (SVM)**:
#    - Accuracy: 32.6%.
#    - Marginally better than Logistic Regression.
#
# 6. **Stochastic Gradient Descent (SGD)**:
#    - Accuracy: 33.1%.
#    - Strong bias toward class 2.0.
#
# 7. **Random Forest**:
#    - Accuracy: 31.8%.
#    - Marginal improvement over Decision Tree but limited by feature overlap.
#
# 8. **Gradient Boosting**:
#    - Accuracy: 32.3%.
#    - Struggled to capture nuanced patterns due to shallow trees.
#
# ### **Key Metrics**:
# - **Precision, Recall, F1-Score**: Consistently poor across models, with biases toward one class (typically class 2.0).
# - **Confusion Matrices**: Highlighted overlaps and failures in class distinction.
#
# ---
#
# ## **Observations and Findings**
# 1. **Data Characteristics**:
#    - Strong feature independence.
#    - Minimal linear relationships among variables.
#    - Limited predictive power in `Quantity` and `Weight`.
#
# 2. **Model Limitations**:
#    - Poor separation of classes across all models.
#    - Features insufficient for effective classification.
#
# 3. **Performance Highlights**:
#    - Slight improvements in ensemble models (Random Forest, Gradient Boosting).
#    - Overall performance plateaued around 32–33% accuracy.
#
# ---
#
# ## **Managerial Insights and Recommendations**
# ### **Managerial Insights and Recommendations**
#
# #### **Managerial Insights**
# 1. **Understanding Trade Dynamics**:
#    - The dataset reveals diverse trade patterns across countries, products, and shipping methods. However, the limited ability of models to predict shipping methods highlights inefficiencies in leveraging existing trade data for decision-making.
#    - The weak correlations between variables (e.g., Value and Weight) suggest the need to understand pricing strategies. High-value items are not necessarily heavy, implying opportunities for optimization in shipping and logistics.
#
# 2. **Operational Efficiency**:
#    - The consistent bias toward specific classes (e.g., Class 2.0 in shipping methods) reflects an operational dependency on certain practices. This over-reliance could create vulnerabilities in supply chain operations, especially during disruptions.
#    - Misclassifications in models indicate that critical features (e.g., Quantity and Weight) alone are insufficient to explain shipping patterns. This suggests that other operational factors, such as delivery urgency, freight charges, or product fragility, might significantly influence shipping decisions.
#
# 3. **Market Diversification**:
#    - The dominance of certain categories (e.g., specific countries, products, or shipping methods) highlights untapped potential in underrepresented segments. Expanding into less explored categories could yield growth opportunities.
#
# 4. **Data and Technology Limitations**:
#    - Current data limitations, such as missing granular details (e.g., freight cost, time sensitivity), hinder the effective use of advanced analytics and machine learning for decision-making.
#    - The lack of non-linear model performance indicates an untapped potential for leveraging more advanced techniques or richer data for better predictions.
#
# ---
#
# #### **Recommendations**
# 1. **Strategic Supply Chain Optimization**:
#    - **Multimodal Logistics**: Explore a mix of shipping methods (land, air, sea) based on region-specific infrastructure and costs. For instance, regions with developed rail networks (like Northern India) could benefit from cost-effective land freight over air freight.
#    - **Dynamic Routing**: Implement technology to dynamically assign shipping methods based on real-time factors such as cost, urgency, and availability.
#
# 2. **Data Enrichment and Real-Time Analytics**:
#    - **Feature Expansion**: Collect additional data points, such as:
#      - Freight cost per unit weight.
#      - Urgency levels of shipments.
#      - Packaging type and product fragility.
#    - **Real-Time Data**: Use IoT devices for real-time tracking and analysis of shipping metrics, enabling more informed decision-making.
#
# 3. **Customer and Supplier Segmentation**:
#    - **Customer Insights**: Analyze trends for frequent customers or suppliers and identify ways to improve service levels, such as offering customized shipping options or bulk discounts.
#    - **Market Expansion**: Leverage insights from underrepresented shipping categories to diversify customer bases, especially focusing on emerging markets in India or globally.
#
# 4. **Technology and Advanced Modeling**:
#    - **AI-Driven Decisions**: Integrate advanced machine learning models (e.g., XGBoost, LightGBM) or deep learning models to capture non-linear relationships and improve predictive capabilities.
#    - **Simulation Tools**: Use simulation techniques to test various shipping scenarios and assess the impact of changes in shipping methods or volumes.
#
# 5. **Cost and Revenue Optimization**:
#    - **Shipping Cost Benchmarks**: Establish benchmarks for shipping costs based on Value-to-Weight ratios. For example, prioritize cost-effective shipping for low-value, heavy items (e.g., furniture) and faster shipping for high-value, lightweight goods (e.g., electronics).
#    - **Dynamic Pricing**: Implement dynamic pricing models for shipping charges based on shipment characteristics and customer preferences.
#
# 6. **Skill Development and Training**:
#    - Upskill teams in supply chain analytics and data-driven decision-making.
#    - Train managers to understand predictive models and interpret their results for operational planning.
#
# 7. **Government and Policy Leverage**:
#    - **Leverage Indian Policies**: Utilize government initiatives like the National Logistics Policy (NLP) to streamline operations and reduce costs.
#    - **Incentives and Subsidies**: Explore export incentives and subsidies provided by Indian trade authorities to reduce shipping costs and improve profit margins.
#
# 8. **Sustainability Focus**:
#    - Adopt greener shipping practices by choosing eco-friendly shipping methods for domestic and international logistics.
#    - Use analytics to calculate and minimize the carbon footprint of shipping operations.

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
# Replace with your Google Drive file ID.
HA13_file_id = '19nTY8-ApKxmEGkfYCrP7tJciREeJ9Ss5' # Import Export Full

# HA13_file_id = '19nTY8-ApKxmEGkfYCrP7tJciREeJ9Ss5' # Import Export with Missing data

# Construct the download HA13_url.
HA13_url = f"https://drive.google.com/uc?id={HA13_file_id}&export=download"

# Download the file content.
HA13_response = requests.get(HA13_url)
HA13_response.raise_for_status()  # Raise an exception for bad HA13_responses (4xx or 5xx)

# Fetch the data using requests
HA13_response = requests.get(HA13_url)
HA13_response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
HA13_data = pd.read_csv(StringIO(HA13_response.text))

# %%
HA13_data.shape
# Out:
# (15000, 16)

# %%
HA13_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables
HA13_index_vars=['Transaction_ID','Invoice_Number']
HA13_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
HA13_ordinal_vars=['Payment_Terms']
HA13_cat_vars= HA13_nominal_vars + HA13_ordinal_vars
HA13_non_cat_vars=['Quantity','Value','Weight']

# %% [markdown]
# DATA SAMPLE

# %%
HA13_sample = pd.DataFrame.sample(HA13_data, n=5001, random_state=55013 ,ignore_index=False)
# Displaying the Dimensions of Sample Data.
HA13_sample.shape
# Out:
# (5001, 16)

# %%
HA13_sample
# Out:
#                              Transaction_ID                Country    Product  \
# 11094  142f9553-5e6a-4af9-a422-7b9ab13afbc1  Sao Tome and Principe       what
# 6150   f3fcdd19-5322-483b-b002-679ce43bb226                Jamaica        can
# 2625   c00276d8-b6b3-457b-826d-3948b4653341            Saint Lucia       risk
# 14671  d0e4209b-4400-4123-8ea9-762b5d5573d8                Grenada      field
# 1104   3de674fe-f66b-42a9-8142-452b361c57ab                 Tuvalu    kitchen
# ...                                     ...                    ...        ...
# 12699  6b07e6b1-af56-48bd-b51f-8f3181fa53f3             Montenegro    perform
# 11404  b05076f4-e2b8-4e71-ac07-4ac9ff3f53ba                Mayotte  newspaper
# 11471  eb4066fb-b363-4780-8456-ec0183d47adb                  India  structure
# 585    567fec5e-04ea-481d-a006-8c1cbbd743b3                Hungary    defense
# 14401  b5e89741-b8db-409c-9c14-2fb8ab18d80d                 Jordan      three
#
# ...

# %%
HA13_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 11094 to 14401
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %% [markdown]
# MISSSING VALUES

# %%
#Missing values
HA13_sample.isnull().sum(axis=1)
# Out:
# 11094    0
# 6150     0
# 2625     0
# 14671    0
# 1104     0
#         ..
# 12699    0
# 11404    0
# 11471    0
# 585      0
# 14401    0
# Length: 5001, dtype: int64

# %% [markdown]
# ENCODING & SCALING

# %%
HA13_oe = OrdinalEncoder()
HA13_categorical_cols = HA13_sample[HA13_cat_vars]
HA13_oe_fit = HA13_oe.fit_transform(HA13_categorical_cols)
HA13_encoded = pd.DataFrame(HA13_oe_fit, columns=HA13_cat_vars)
HA13_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0    190.0    924.0            1.0       0.0  1874.0              0.0
# 1    107.0    134.0            0.0       0.0  3948.0              1.0
# 2    184.0    705.0            0.0       1.0  3824.0              0.0
# 3     84.0    301.0            1.0       3.0  2468.0              0.0
# 4    225.0    435.0            1.0       2.0  1782.0              1.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    3976.0     793.0        3870.0            1.0
# 1    2610.0    1748.0        2293.0            3.0
# 2    1671.0     819.0        3776.0            3.0
# 3    2776.0    3296.0         486.0            1.0
# 4    1768.0    4347.0         641.0            0.0

# %%
#SCALING
HA13_scaler = MinMaxScaler()
HA13_scaled_data = HA13_scaler.fit_transform(HA13_sample[HA13_non_cat_vars])
HA13_scaled = pd.DataFrame(HA13_scaled_data, columns=HA13_non_cat_vars)
HA13_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.281707  0.514628  0.598654
# 1  0.109297  0.802252  0.807648
# 2  0.638149  0.580596  0.861157
# 3  0.212783  0.759919  0.238085
# 4  0.794330  0.149921  0.970008

# %%
HA13_processed = pd.concat([HA13_scaled, HA13_encoded], axis=1)
HA13_processed.head()
HA13_sample = HA13_processed
HA13_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.281707  0.514628  0.598654    190.0    924.0            1.0       0.0
# 1  0.109297  0.802252  0.807648    107.0    134.0            0.0       0.0
# 2  0.638149  0.580596  0.861157    184.0    705.0            0.0       1.0
# 3  0.212783  0.759919  0.238085     84.0    301.0            1.0       3.0
# 4  0.794330  0.149921  0.970008    225.0    435.0            1.0       2.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0  1874.0              0.0    3976.0     793.0        3870.0            1.0
# 1  3948.0              1.0    2610.0    1748.0        2293.0            3.0
# 2  3824.0              0.0    1671.0     819.0        3776.0            3.0
# 3  2468.0              0.0    2776.0    3296.0         486.0            1.0
# 4  1782.0              1.0    1768.0    4347.0         641.0            0.0

# %% [markdown]
# STATISTICS

# %%
HA13_sample[HA13_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean      0.500652     0.500853     0.494203
# std       0.286524     0.287122     0.292535
# min       0.000000     0.000000     0.000000
# 25%       0.252755     0.252576     0.240561
# 50%       0.502304     0.502013     0.486497
# 75%       0.747145     0.748176     0.748554
# max       1.000000     1.000000     1.000000

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in HA13_sample[HA13_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
HA13_summary_stats = summarize_numerical(HA13_sample,HA13_non_cat_vars)
HA13_summary_data = pd.DataFrame.from_dict(HA13_summary_stats, orient='index')
HA13_summary_data
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.427169    1.0  0.007022 -1.177971
# Value     0.005237    1.0  0.007807 -1.189915
# Weight    0.063372    1.0  0.040621 -1.209167

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in HA13_non_cat_vars:
    cv_results[col] = coefficient_of_variation(HA13_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 57.23%
# Value: 57.33%
# Weight: 59.19%

# %%
import numpy as np
from scipy import stats

# Confidence Interval Function
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for the given confidence level
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

# Confidence Intervals for Non-Categorical Variables
ci_results = {}
for col in HA13_non_cat_vars:
    ci_results[col] = confidence_interval(HA13_sample[col])

# Print Results
print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.51
# Value: 0.49 to 0.51
# Weight: 0.49 to 0.50

# %%
correlation_data = HA13_sample[HA13_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000 -0.008187  0.013954
# Value    -0.008187  1.000000 -0.001918
# Weight    0.013954 -0.001918  1.000000

# %%
print(HA13_sample.columns)
# Out:
# Index(['Quantity', 'Value', 'Weight', 'Country', 'Product', 'Import_Export',
#        'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer',
#        'Customs_Code', 'Payment_Terms'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 5))
pastel_cmap = sns.color_palette("pastel", as_cmap=True)
sns.heatmap(correlation_matrix, annot=True, cmap=pastel_cmap, linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Categorical Data

def HA13_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

HA13_categorical_summaries = HA13_categorical_summary(HA13_sample, HA13_cat_vars)

for col, stats in HA13_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 114.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 966.0
#   Mode: 934.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 3.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4300.0
#   Mode: 1983.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 2.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4564.0
#   Mode: 3763.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4821.0
#   Mode: 3342.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
# ...

# %%
print(HA13_sample.columns)
# Out:
# Index(['Quantity', 'Value', 'Weight', 'Country', 'Product', 'Import_Export',
#        'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer',
#        'Customs_Code', 'Payment_Terms'],
#       dtype='object')

# %%
import plotly.express as px
import pandas as pd
import numpy as np
HA13_sample1 = pd.DataFrame({
    'Quantity': np.random.rand(5001),
    'Value': np.random.rand(5001),
    'Weight': np.random.rand(5001)
})
HA13_non_cat_vars = ['Quantity', 'Value', 'Weight']
for col in HA13_non_cat_vars:
    fig = px.histogram(
        HA13_sample1,
        x=col,
        nbins=30,
        marginal="violin",  # Adds a KDE violin plot
        title=f'Distribution of {col}',
        color_discrete_sequence=px.colors.qualitative.Pastel  # Pastel color palette
    )
    fig.update_layout(
        xaxis_title=col,
        yaxis_title="Frequency",
        template="simple_white"
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
HA13_sample_1 = pd.DataFrame({
    'Quantity': np.random.rand(5001),
    'Value': np.random.rand(5001),
    'Weight': np.random.rand(5001)
})
HA13_non_cat_vars = ['Quantity', 'Value', 'Weight']

# Box plots
plt.figure(figsize=(15, 10))
pastel_colors = sns.color_palette("pastel")

for i, col in enumerate(HA13_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=HA13_sample_1[col], palette=[pastel_colors[i % len(pastel_colors)]])
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-179-f27b36f1a21b>:14: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-179-f27b36f1a21b>:14: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-179-f27b36f1a21b>:14: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
print(HA13_sample.columns)
# Out:
# Index(['Quantity', 'Value', 'Weight', 'Country', 'Product', 'Import_Export',
#        'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer',
#        'Customs_Code', 'Payment_Terms'],
#       dtype='object')

# %%
# Test of Homogeneity {Chi-sq} on categorical data

HA13_contingency_table = pd.crosstab(HA13_sample['Import_Export'], HA13_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(HA13_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
HA13_alpha = 0.05  # Significance level

if p < HA13_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 8.801075452253151
# P-value: 0.06626859338648587
# Degrees of freedom: 4
# Expected frequencies:
# [[505.5884823  505.5884823  486.62267546 515.5704859  482.62987403]
#  [507.4115177  507.4115177  488.37732454 517.4295141  484.37012597]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    HA13_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    HA13_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    HA13_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    HA13_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    HA13_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return HA13_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in HA13_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(HA13_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(HA13_non_cat_vars) > 1:
        for i in range(len(HA13_non_cat_vars)):
            for j in range(i+1, len(HA13_non_cat_vars)):
                col1, col2 = HA13_non_cat_vars[i], HA13_non_cat_vars[j]
                t_test_result = t_test_correlation(HA13_sample[col1], HA13_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9569913568624913, 'p-value': 4.486897407711377e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 51.63913044885521, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 289.19646838902224, 'p-value': 1.5914199437923906e-63}
# T-test Correlation between Quantity and Value: {'t-statistic': -0.03517031956474514, 'p-value': 0.9719446311103221}
# T-test Correlation between Quantity and Weight: {'t-statistic': 1.1136328556642228, 'p-value': 0.2654634917208768}
# T-test Correlation between Value and Weight: {'t-statistic': 1.1472991000018147, 'p-value': 0.251285473763496}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9554196766504836, 'p-value': 1.368200130498787e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
# ...

# %%
HA13_X = HA13_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
HA13_y = HA13_processed[['Shipping_Method']]  # Target variable

HA13_X_train, HA13_X_test, HA13_y_train, HA13_y_test = train_test_split(HA13_X, HA13_y, test_size=0.3, random_state=55013)

# Print the shapes of the resulting datasets
print("X_train shape:", HA13_X_train.shape)
print("X_test shape:", HA13_X_test.shape)
print("y_train shape:", HA13_y_train.shape)
print("y_test shape:", HA13_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=55013)

# Train the model on the training data
dt_model.fit(HA13_X_train, HA13_y_train)

# Initialize the Decision Tree Classifier
HA13_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55011)

# Train the model
HA13_dt_classifier.fit(HA13_X_train, HA13_y_train)

# Make predictions on the test set
HA13_y_pred_dt = HA13_dt_classifier.predict(HA13_X_test)

# Make predictions on the test set
HA13_y_pred_dt = HA13_dt_classifier.predict(HA13_X_test)

# Evaluate the model
HA13_accuracy_dt = accuracy_score(HA13_y_test, HA13_y_pred_dt)
print(f"Decision Tree Accuracy: {HA13_accuracy_dt}")
print(classification_report(HA13_y_test, HA13_y_pred_dt))

# Evaluate the model
print("Accuracy:", accuracy_score(HA13_y_test, HA13_y_pred))
print("\nClassification Report:\n", classification_report(HA13_y_test, HA13_y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(HA13_y_test, HA13_y_pred))

# Visualize the Decision Tree
plt.figure(figsize=(15, 10))
plot_tree(dt_model, feature_names=['Quantity', 'Weight'], class_names=dt_model.classes_.astype(str), filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Decision Tree Accuracy: 0.31645569620253167
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.32      0.32       505
#          1.0       0.32      0.31      0.32       499
#          2.0       0.30      0.32      0.31       497
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501
#
# Accuracy: 0.3151232511658894
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.33      0.31      0.32       505
#          1.0       0.33      0.31      0.32       499
#          2.0       0.29      0.32      0.30       497
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501
#
#
# Confusion Matrix:
#  [[156 147 202]
#  [146 157 196]
#  [171 166 160]]

# %%
# Confusion matrix

HA13_cm = confusion_matrix(HA13_y_test, HA13_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(HA13_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=HA13_dt_classifier.classes_, yticklabels=HA13_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


#Create and train the KNN classifier
HA13_knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
HA13_knn.fit(HA13_X_train, HA13_y_train)

#Make predictions on the test set
HA13_y_pred = HA13_knn.predict(HA13_X_test)

#Evaluate the model
HA13_accuracy_knn = accuracy_score(HA13_y_test, HA13_y_pred)
print(f"Accuracy: {HA13_accuracy_knn}")
print(classification_report(HA13_y_test, HA13_y_pred))
# Out:
# Accuracy: 0.32378414390406396
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.46      0.39       505
#          1.0       0.33      0.31      0.32       499
#          2.0       0.28      0.20      0.24       497
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

#Create and train the Naive Bayes classifier
HA13_nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
HA13_nb.fit(HA13_X_train, HA13_y_train)

#Make predictions on the test set
HA13_y_pred = HA13_nb.predict(HA13_X_test)

#Evaluate the model
HA13_accuracy_nb = accuracy_score(HA13_y_test, HA13_y_pred)
print(f"Accuracy: {HA13_accuracy_nb}")
print(classification_report(HA13_y_test, HA13_y_pred))
# Out:
# Accuracy: 0.32045303131245834
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.34      0.33       505
#          1.0       0.17      0.00      0.00       499
#          2.0       0.32      0.62      0.42       497
#
#     accuracy                           0.32      1501
#    macro avg       0.27      0.32      0.25      1501
# weighted avg       0.27      0.32      0.25      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
#Create and train the Naive Bayes classifier
HA13_nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
HA13_nb.fit(HA13_X_train, HA13_y_train)

#Make predictions on the test set
HA13_y_pred = HA13_nb.predict(HA13_X_test)

#Evaluate the model
HA13_accuracy_nb = accuracy_score(HA13_y_test, HA13_y_pred)
print(f"Accuracy: {HA13_accuracy_nb}")
print(classification_report(HA13_y_test, HA13_y_pred))
# Out:
# Accuracy: 0.32045303131245834
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.34      0.33       505
#          1.0       0.17      0.00      0.00       499
#          2.0       0.32      0.62      0.42       497
#
#     accuracy                           0.32      1501
#    macro avg       0.27      0.32      0.25      1501
# weighted avg       0.27      0.32      0.25      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
# Initialize the Logistic Regression model
HA13_logreg_classifier = LogisticRegression(random_state=55013)

# Train the model
HA13_logreg_classifier.fit(HA13_X_train, HA13_y_train)

# Make predictions on the test set
HA13_y_pred_logreg = HA13_logreg_classifier.predict(HA13_X_test)

# Evaluate the model
HA13_accuracy_logreg = accuracy_score(HA13_y_test, HA13_y_pred_logreg)
print(f"Logistic Regression Accuracy: {HA13_accuracy_logreg}")
print(classification_report(HA13_y_test, HA13_y_pred_logreg))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Logistic Regression Accuracy: 0.3224516988674217
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.34      0.33       505
#          1.0       0.00      0.00      0.00       499
#          2.0       0.32      0.63      0.42       497
#
#     accuracy                           0.32      1501
#    macro avg       0.22      0.32      0.25      1501
# weighted avg       0.22      0.32      0.25      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...

# %%
# Confusion Matrix for Logistic Regression
HA13_cm_logreg = confusion_matrix(HA13_y_test, HA13_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(HA13_cm_logreg, annot=True, fmt='d', cmap=sns.color_palette("pastel", as_cmap=True),  # Pastel colormap
            xticklabels=HA13_logreg_classifier.classes_, yticklabels=HA13_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
# Initialize the Logistic Regression model
HA13_logreg_classifier = LogisticRegression(random_state=55011)

# Set up K-Fold Cross-Validation
HA13_kfold = KFold(n_splits=5, shuffle=True, random_state=55011)

# Perform Cross-Validation
HA13_cv_accuracy = cross_val_score(HA13_logreg_classifier, HA13_X_train, HA13_y_train, cv=HA13_kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", HA13_cv_accuracy)
print("Mean Accuracy: ", HA13_cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", HA13_cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
HA13_logreg_classifier.fit(HA13_X_train, HA13_y_train)

# Evaluate the model on the test set
HA13_y_pred_logreg = HA13_logreg_classifier.predict(HA13_X_test)
HA13_accuracy_logreg = accuracy_score(HA13_y_test, HA13_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {HA13_accuracy_logreg}")
print(classification_report(HA13_y_test, HA13_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.34142857 0.35142857 0.38142857 0.35142857 0.32142857]
# Mean Accuracy:  0.3494285714285714
# Standard Deviation of Accuracy:  0.019390719429665318
# Logistic Regression Test Set Accuracy: 0.3224516988674217
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.34      0.33       505
#          1.0       0.00      0.00      0.00       499
#          2.0       0.32      0.63      0.42       497
#
#     accuracy                           0.32      1501
#    macro avg       0.22      0.32      0.25      1501
# weighted avg       0.22      0.32      0.25      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# ...

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
HA13_svm_classifier = SVC(kernel='linear', random_state=55011)

# Set up K-Fold Cross-Validation
HA13_kfold = KFold(n_splits=5, shuffle=True, random_state=55011)

# Perform Cross-Validation
HA13_cv_accuracy = cross_val_score(HA13_svm_classifier, HA13_X_train, HA13_y_train, cv=HA13_kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", HA13_cv_accuracy)
print("Mean Accuracy: ", HA13_cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", HA13_cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
HA13_svm_classifier.fit(HA13_X_train, HA13_y_train)

# Evaluate the model on the test set
HA13_y_pred_svm = HA13_svm_classifier.predict(HA13_X_test)
HA13_accuracy_svm = accuracy_score(HA13_y_test, HA13_y_pred_svm)
print(f"SVM Test Set Accuracy: {HA13_accuracy_svm}")
print(classification_report(HA13_y_test, HA13_y_pred_svm))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# ...

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
HA13_sgd_classifier = SGDClassifier(loss='log_loss', random_state=55011, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
HA13_kfold = KFold(n_splits=5, shuffle=True, random_state=55011)

# 3. Perform Cross-Validation
HA13_cv_accuracy = cross_val_score(HA13_sgd_classifier, HA13_X_train, HA13_y_train, cv=HA13_kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", HA13_cv_accuracy)
print("Mean Accuracy: ", HA13_cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", HA13_cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
HA13_sgd_classifier.fit(HA13_X_train, HA13_y_train)

# 6. Make predictions on the test set
HA13_y_pred_sgd = HA13_sgd_classifier.predict(HA13_X_test)

# 7. Evaluate the Model
HA13_accuracy_sgd = accuracy_score(HA13_y_test, HA13_y_pred_sgd)
print(f"SGD Test Set Accuracy: {HA13_accuracy_sgd}")
print(classification_report(HA13_y_test, HA13_y_pred_sgd))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# ...

# %%
print(f"Logistic Regression Accuracy: {HA13_accuracy_logreg}")
print(f"SVM Accuracy: {HA13_accuracy_svm}")

if HA13_accuracy_logreg > HA13_accuracy_svm:
    print("Logistic Regression model performs better.")
elif HA13_accuracy_svm > HA13_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3224516988674217
# SVM Accuracy: 0.3264490339773484
# Support Vector Machine model performs better.

# %%
print(f"Logistic Regression Accuracy: {HA13_accuracy_logreg}")
print(f"SGD Accuracy: {HA13_accuracy_sgd}")

if HA13_accuracy_logreg > HA13_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif HA13_accuracy_sgd > HA13_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3224516988674217
# SGD Accuracy: 0.33111259160559625
# Stochastic Gradient Descent model performs better.

# %%
print(f"Decision Tree Accuracy: {HA13_accuracy_dt}")
print(f"KNN Accuracy: {HA13_accuracy_knn}")

if HA13_accuracy_dt > HA13_accuracy_knn:
    print("Decision Tree model performs better.")
elif HA13_accuracy_knn > HA13_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31645569620253167
# KNN Accuracy: 0.32378414390406396
# K Nearest Neighbour model performs better.

# %%
print(f"Logistic Regression Accuracy: {HA13_accuracy_logreg}")
print(f"Decision Tree Accuracy: {HA13_accuracy_dt}")

if HA13_accuracy_logreg > HA13_accuracy_dt:
    print("Logistic Regression model performs better.")
elif HA13_accuracy_dt > HA13_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3224516988674217
# Decision Tree Accuracy: 0.31645569620253167
# Logistic Regression model performs better.

# %%
print(f"Decision Tree Accuracy: {HA13_accuracy_dt}")
print(f"Naive Bayes Accuracy: {HA13_accuracy_nb}")

if HA13_accuracy_dt > HA13_accuracy_nb:
    print("Decision Tree model performs better.")
elif HA13_accuracy_nb > HA13_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31645569620253167
# Naive Bayes Accuracy: 0.32045303131245834
# Naive Bayes model performs better.

# %%
# Initialize the Random Forest Classifier
HA13_rf_classifier = RandomForestClassifier(random_state=55011)

# Train the model
HA13_rf_classifier.fit(HA13_X_train, HA13_y_train)

# Make predictions on the test set
HA13_y_pred_rf = HA13_rf_classifier.predict(HA13_X_test)

# Evaluate the model
HA13_accuracy_rf = accuracy_score(HA13_y_test, HA13_y_pred_rf)
print(f"Random Forest Accuracy: {HA13_accuracy_rf}")
print(classification_report(HA13_y_test, HA13_y_pred_rf))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Random Forest Accuracy: 0.31778814123917387
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.31      0.31       505
#          1.0       0.34      0.30      0.32       499
#          2.0       0.30      0.35      0.32       497
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501

# %%
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import graphviz

# Visualize one of the trees in the Random Forest
plt.figure(figsize=(30, 15))
tree_index = 0  # Index of the tree to visualize
tree = HA13_rf_classifier.estimators_[tree_index]

# Plot the tree
plot_tree(
    tree,
    feature_names=['Quantity', 'Weight'],
    class_names=HA13_rf_classifier.classes_.astype(str),
    filled=True,
    rounded=True,
    fontsize=10
)
plt.title(f"Decision Tree {tree_index + 1} from the Random Forest")
plt.show()

# Optional: Save the tree to a file for better resolution
export_graphviz(
    tree,
    out_file="tree.dot",
    feature_names=['Quantity', 'Weight'],
    class_names=HA13_rf_classifier.classes_.astype(str),
    rounded=True,
    filled=True
)

# %%
# Confusion Matrix for Random Forest
HA13_cm_rf = confusion_matrix(HA13_y_test, HA13_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(HA13_cm_rf, annot=True, fmt='d', cmap=sns.color_palette("pastel", as_cmap=True),  # Pastel colormap
            xticklabels=HA13_rf_classifier.classes_, yticklabels=HA13_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
HA13_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=55011).fit(HA13_X_train, HA13_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",HA13_clf.score(HA13_X_test, HA13_y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# The mean accuracy on the given test data and labels from Extreme Gradient Boosting is 0.32311792138574286

# %% [markdown]
# # **OBSERVATIONS:**
# The mean accuracy of 0.3231 (rounded to four decimal places) suggests that the XGBoost model, on average, correctly classifies approximately 32.31% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {HA13_accuracy_dt}")
print(f"Random Forest Accuracy: {HA13_accuracy_rf}")

if HA13_accuracy_rf > HA13_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif HA13_accuracy_dt > HA13_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31645569620253167
# Random Forest Accuracy: 0.31778814123917387
# Random Forest performs better than Decision Tree.
